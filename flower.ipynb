# %%
import matplotlib.pyplot as plt

flower = plt.imread('assets/flower.png')

flower[:100, : 0] = 1
flower
# Out:
# array([[[0.3254902 , 0.48235294, 0.78431374, 1.        ],
#         [0.3254902 , 0.48235294, 0.78431374, 1.        ],
#         [0.3254902 , 0.47843137, 0.78431374, 1.        ],
#         ...,
#         [0.39215687, 0.4745098 , 0.26666668, 1.        ],
#         [0.39607844, 0.47843137, 0.2627451 , 1.        ],
#         [0.39607844, 0.4862745 , 0.2627451 , 1.        ]],
#
#        [[0.32941177, 0.49019608, 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         ...,
#         [0.39607844, 0.48235294, 0.2627451 , 1.        ],
#         [0.4       , 0.49019608, 0.2627451 , 1.        ],
#         [0.40392157, 0.49411765, 0.2627451 , 1.        ]],
#
#        [[0.32941177, 0.49019608, 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         [0.32941177, 0.4862745 , 0.79607844, 1.        ],
#         ...,
# ...

# %%
plt.imshow(flower)
plt.show()
