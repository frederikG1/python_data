# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1, 2, 3, 4])
y = [10, 12, 14, 16]

plt.bar(x, y)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
x = np.linspace(0, 200, 400)

y1 = x
y2 = x/2
y3 = np.log2(x)

plt.plot(x, y1, label='n', color='red')
plt.plot(x, y2, label='n/2', color='blue')
plt.plot(x, y3, label='log2(n)', color='black')

plt.title('Big o notation')
plt.legend()

plt.ylim(0,12)
plt.xlim(0,200)


plt.xlabel('Input size(n)')
plt.ylabel('Time complexity')

plt.grid(True)
plt.show()
# Out:
# C:\Users\frede\AppData\Local\Temp\ipykernel_21160\4189158873.py:5: RuntimeWarning: divide by zero encountered in log2
#   y3 = np.log2(x)
